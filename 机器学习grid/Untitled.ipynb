# %%
#导入模块
import numpy as np
 
#创建加载数据读取数据以及划分数据集的函数，返回数据特征集以及数据标签集
def loaddataset(filename):
    fp = open(filename)#（299，22）
 
    # 存放数据
    dataset = []
 
    # 存放标签
    labelset = []
    for i in fp.readlines():#按照行来进行读取，每次读取一行，一行的数据作为一个元素存放在了类别中
        a = i.strip().split()#去掉每一行数据的空格以及按照默认的分隔符进行划分
 
        # 每个数据行的最后一个是标签
        dataset.append([float(j) for j in a[:len(a) - 1]])#读取每一行中除最后一个元素的前面的元素，并且将其转换为浮点数
        labelset.append(int(float(a[-1])))#读取每一行的最后一个数据作为标签数据
    return dataset, labelset#dataset是（299,21）的列表，labelset是（299,1）的列表
 
 
# x为输入层神经元个数，y为隐层神经元个数，z输出层神经元个数
#创建的是参数初始化函数，参数有各层间的权重weight和阈值即偏置value就是b
#本例的x,y=len(dataset[0])=22，z=1
def parameter_initialization(x, y, z):
    # 隐层阈值
    value1 = np.random.randint(-5, 5, (1, y)).astype(np.float64)
    #随机生成（-5，5）之间的整数组成（1，y）的数组，然后再将其转为浮点数显示
 
    # 输出层阈值
    value2 = np.random.randint(-5, 5, (1, z)).astype(np.float64)
 
    # 输入层与隐层的连接权重
    weight1 = np.random.randint(-5, 5, (x, y)).astype(np.float64)
 
    # 隐层与输出层的连接权重
    weight2 = np.random.randint(-5, 5, (y, z)).astype(np.float64)
 
    return weight1, weight2, value1, value2
 
#创建激活函数sigmoid
def sigmoid(z):
    return 1 / (1 + np.exp(-z))
 
 
'''
weight1:输入层与隐层的连接权重
weight2:隐层与输出层的连接权重
value1:隐层阈值
value2:输出层阈值
权重和阈值的个数和神经网络的隐层层数有关，若隐层为n，则权重和阈值的个数为n+1
'''
 
#创建训练样本的函数，返回训练完成后的参数weight和value，这里的函数是经过一次迭代后的参数，即所有的样本经过一次训练后的参数
#具体参数的值可以通过设置迭代次数和允许误差来进行确定
def trainning(dataset, labelset, weight1, weight2, value1, value2):
    # x为步长
    x = 0.01#学习率
    for i in range(len(dataset)):#依次读取数据特征集中的元素，一个元素即为一个样本所含有的所有特征数据
 
        # 输入数据
        #（1,21）
        inputset = np.mat(dataset[i]).astype(np.float64)#每次输入一个样本，将样本的特征转化为矩阵，以浮点数显示
 
        # 数据标签
        #（1，1）
        outputset = np.mat(labelset[i]).astype(np.float64)#输入样本所对应的标签
 
        # 隐层输入，隐层的输入是由输入层的权重决定的，wx
        #input1：（1，21）.（21，21）=（1，21）
        input1 = np.dot(inputset, weight1).astype(np.float64)
 
        # 隐层输出，由隐层的输入和阈值以及激活函数决定的，这里的阈值也可以放在输入进行计算
        #sigmoid（（1，21）-（1，21））=（1，21）
        output2 = sigmoid(input1 - value1).astype(np.float64)
 
        # 输出层输入，由隐层的输出
        #（1，21）.（21，1）=（1，1）
        input2 = np.dot(output2, weight2).astype(np.float64)
 
        # 输出层输出，由输出层的输入和阈值以及激活函数决定的，这里的阈值也可以放在输出层输入进行计算
        # （1，1）.（1，1）=（1，1）
        output3 = sigmoid(input2 - value2).astype(np.float64)
 
 
        # 更新公式由矩阵运算表示
        #a:(1,1)
        a = np.multiply(output3, 1 - output3)#输出层激活函数求导后的式子，multiply对应元素相乘，dot矩阵运算
        #g:(1,1)
        g = np.multiply(a, outputset - output3)#outputset - output3：实际标签和预测标签差
        #weight2:(21,1),np.transpose(weight2):(1,21),b:(1,21)
        b = np.dot(g, np.transpose(weight2))
        #(1,21)
        c = np.multiply(output2, 1 - output2)#隐层输出激活函数求导后的式子，multiply对应元素相乘，dot矩阵运算
        #(1,21)
        e = np.multiply(b, c)
 
        value1_change = -x * e#（1，21）
        value2_change = -x * g#（1，1）
        weight1_change = x * np.dot(np.transpose(inputset), e)#（21，21）
        weight2_change = x * np.dot(np.transpose(output2), g)#（21，1）
 
        # 更新参数，权重与阈值的迭代公式
        value1 += value1_change
        value2 += value2_change
        weight1 += weight1_change
        weight2 += weight2_change
    return weight1, weight2, value1, value2
 
#创建测试样本数据的函数
def testing(dataset1, labelset1, weight1, weight2, value1, value2):
    # 记录预测正确的个数
    rightcount = 0
    for i in range(len(dataset1)):
        # 计算每一个样例的标签通过上面创建的神经网络模型后的预测值
        inputset = np.mat(dataset1[i]).astype(np.float64)
        outputset = np.mat(labelset1[i]).astype(np.float64)
        output2 = sigmoid(np.dot(inputset, weight1) - value1)
        output3 = sigmoid(np.dot(output2, weight2) - value2)
 
        # 确定其预测标签
        if output3 > 0.5:
            flag = 1
        else:
            flag = 0
        if labelset1[i] == flag:
            rightcount += 1
        # 输出预测结果
        print("预测为%d   实际为%d   评价为%f" % (flag, labelset1[i], output3))
    # 返回正确率
    return rightcount / len(dataset1)
 
def main():
    #读取训练样本数据并且进行样本划分
    dataset, labelset = loaddataset('./in4-1.txt')
    #读取测试样本数据并且进行样本划分
    dataset1, labelset1 = loaddataset('./test4-1.txt')
    #得到初始化的待估参数的值
    weight1, weight2, value1, value2 = parameter_initialization(len(dataset[0]), len(dataset[0]), 1)
    #迭代次数为1500次，迭代次数一般越大准确率越高，但是其运行时间也会增加
    for i in range(1500):
        #获得对所有训练样本训练迭代一次后的待估参数
        weight1, weight2, value1, value2 = trainning(dataset, labelset, weight1, weight2, value1, value2)
    #对测试样本进行测试，并且得到正确率
    rate = testing(dataset1, labelset1, weight1, weight2, value1, value2)
    print("正确率为%f" % (rate))
if __name__ == '__main__':
    main()
# Out:
# <ipython-input-8-8e4c362dfcfd>:43: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))
# 预测为0   实际为0   评价为0.000001
# 预测为0   实际为0   评价为0.292676
# 预测为0   实际为0   评价为0.161372
# 预测为0   实际为0   评价为0.035445
# 预测为0   实际为0   评价为0.000314
# 预测为0   实际为0   评价为0.341183
# 预测为0   实际为0   评价为0.301865
# 预测为0   实际为0   评价为0.000119
# 预测为0   实际为0   评价为0.001507
# 预测为0   实际为0   评价为0.166745
# 预测为0   实际为0   评价为0.310565
# 预测为1   实际为0   评价为0.546033
# 预测为0   实际为0   评价为0.376019
# 预测为0   实际为0   评价为0.206215
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.000008
# 预测为0   实际为0   评价为0.119589
# 预测为0   实际为0   评价为0.137507
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.083640
# 预测为0   实际为0   评价为0.186762
# 预测为0   实际为0   评价为0.102691
# 预测为0   实际为0   评价为0.000438
# 预测为1   实际为0   评价为0.637153
# 预测为1   实际为0   评价为0.672187
# 预测为0   实际为0   评价为0.381344
# 预测为0   实际为0   评价为0.070747
# 预测为0   实际为0   评价为0.256962
# 预测为0   实际为0   评价为0.002184
# 预测为0   实际为0   评价为0.113262
# 预测为1   实际为0   评价为0.522536
# 预测为0   实际为0   评价为0.000011
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.076683
# 预测为0   实际为0   评价为0.102511
# 预测为0   实际为0   评价为0.285087
# 预测为0   实际为0   评价为0.015520
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.000000
# 预测为1   实际为0   评价为0.504354
# 预测为0   实际为0   评价为0.428765
# 预测为1   实际为0   评价为0.553638
# 预测为0   实际为0   评价为0.075701
# 预测为0   实际为0   评价为0.063850
# 预测为0   实际为0   评价为0.000007
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.000371
# 预测为0   实际为0   评价为0.265606
# 预测为0   实际为0   评价为0.072517
# 预测为0   实际为0   评价为0.126268
# 预测为0   实际为0   评价为0.266529
# 预测为0   实际为0   评价为0.266529
# 预测为0   实际为0   评价为0.264858
# 预测为0   实际为0   评价为0.264858
# 预测为0   实际为0   评价为0.084097
# 预测为1   实际为0   评价为0.571998
# 预测为0   实际为0   评价为0.177675
# 预测为0   实际为0   评价为0.326911
# 预测为0   实际为0   评价为0.337478
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.311641
# 预测为1   实际为0   评价为0.550438
# 预测为0   实际为0   评价为0.183881
# 预测为0   实际为0   评价为0.342961
# 预测为1   实际为0   评价为0.727442
# 预测为0   实际为0   评价为0.488898
# 预测为0   实际为0   评价为0.076838
# 预测为0   实际为0   评价为0.072640
# 预测为0   实际为0   评价为0.000002
# 预测为0   实际为0   评价为0.000001
# 预测为0   实际为0   评价为0.024681
# 预测为0   实际为0   评价为0.000000
# 预测为0   实际为0   评价为0.458177
# 预测为1   实际为0   评价为0.564371
# 预测为0   实际为0   评价为0.000001
# 预测为1   实际为0   评价为0.525869
# 预测为1   实际为0   评价为0.841718
# 预测为1   实际为1   评价为0.602792
# 预测为0   实际为1   评价为0.496336
# 预测为1   实际为1   评价为0.656999
# 预测为1   实际为1   评价为0.825325
# 预测为0   实际为1   评价为0.257118
# 预测为1   实际为1   评价为0.502745
# 预测为0   实际为1   评价为0.383661
# 预测为0   实际为1   评价为0.103114
# 预测为0   实际为1   评价为0.263904
# 预测为0   实际为1   评价为0.497709
# 预测为0   实际为1   评价为0.337708
# 预测为0   实际为1   评价为0.482039
# 预测为1   实际为1   评价为0.713290
# 预测为1   实际为1   评价为0.789628
# 预测为1   实际为1   评价为0.729571
# 预测为1   实际为1   评价为0.668102
# 预测为0   实际为1   评价为0.152064
# 预测为0   实际为1   评价为0.356826
# 预测为1   实际为1   评价为0.613497
# 预测为1   实际为1   评价为0.517523
# 预测为0   实际为1   评价为0.393334
# 预测为0   实际为1   评价为0.409911
# 预测为0   实际为1   评价为0.251387
# 预测为0   实际为1   评价为0.252840
# 预测为0   实际为1   评价为0.368365
# 预测为0   实际为1   评价为0.145996
# 预测为1   实际为1   评价为0.562840
# 预测为0   实际为1   评价为0.022977
# 预测为0   实际为1   评价为0.014290
# 预测为0   实际为1   评价为0.014335
# 预测为1   实际为1   评价为0.650612
# 预测为1   实际为1   评价为0.543919
# 预测为1   实际为1   评价为0.750547
# 预测为1   实际为1   评价为0.741316
# 预测为1   实际为1   评价为0.660615
# 预测为1   实际为1   评价为0.675953
# 预测为1   实际为1   评价为0.528525
# 预测为0   实际为1   评价为0.420147
# 预测为0   实际为1   评价为0.457556
# 预测为0   实际为1   评价为0.287154
# 预测为0   实际为1   评价为0.290786
# 预测为0   实际为1   评价为0.283063
# 预测为1   实际为1   评价为0.506353
# 预测为0   实际为1   评价为0.290429
# 预测为1   实际为1   评价为0.587683
# 预测为1   实际为1   评价为0.749646
# 预测为0   实际为1   评价为0.425036
# 预测为0   实际为1   评价为0.346662
# 预测为0   实际为1   评价为0.417007
# 预测为1   实际为1   评价为0.554222
# 预测为0   实际为1   评价为0.406686
# 预测为0   实际为1   评价为0.206983
# 预测为1   实际为1   评价为0.529615
# 预测为1   实际为1   评价为0.689614
# 预测为1   实际为1   评价为0.753734
# 预测为1   实际为1   评价为0.783154
# 预测为0   实际为1   评价为0.259237
# 预测为0   实际为1   评价为0.423200
# 预测为0   实际为1   评价为0.355875
# 预测为0   实际为1   评价为0.109225
# 预测为0   实际为1   评价为0.495513
# 预测为1   实际为1   评价为0.506966
# 预测为0   实际为1   评价为0.373083
# 预测为1   实际为1   评价为0.552408
# 预测为1   实际为1   评价为0.672700
# 预测为1   实际为1   评价为0.554990
# 预测为1   实际为1   评价为0.678507
# 预测为1   实际为1   评价为0.512696
# 预测为0   实际为1   评价为0.306656
# 预测为1   实际为1   评价为0.700862
# 预测为1   实际为1   评价为0.527116
# 预测为1   实际为1   评价为0.582636
# 预测为1   实际为1   评价为0.536378
# 预测为1   实际为1   评价为0.682921
# 预测为0   实际为1   评价为0.016070
# 预测为0   实际为1   评价为0.016824
# 预测为0   实际为1   评价为0.019576
# 预测为0   实际为1   评价为0.020465
# 预测为0   实际为1   评价为0.022758
# 预测为1   实际为1   评价为0.554947
# 预测为1   实际为1   评价为0.547427
# 预测为1   实际为1   评价为0.500583
# 预测为1   实际为1   评价为0.587443
# 预测为0   实际为1   评价为0.428603
# 预测为1   实际为1   评价为0.618279
# 预测为1   实际为1   评价为0.849901
# 预测为1   实际为1   评价为0.622990
# 预测为0   实际为1   评价为0.240945
# 预测为1   实际为1   评价为0.861048
# 预测为0   实际为1   评价为0.282561
# 预测为1   实际为1   评价为0.587503
# 预测为0   实际为1   评价为0.337550
# 预测为0   实际为1   评价为0.322774
# 预测为1   实际为1   评价为0.568782
# 预测为0   实际为1   评价为0.476291
# 预测为0   实际为1   评价为0.440732
# 预测为0   实际为1   评价为0.375482
# 预测为0   实际为1   评价为0.344419
# 预测为1   实际为1   评价为0.693402
# 预测为1   实际为1   评价为0.747184
# 预测为1   实际为1   评价为0.523563
# 预测为1   实际为1   评价为0.709414
# 预测为1   实际为1   评价为0.529791
# 预测为0   实际为1   评价为0.170751
# 预测为0   实际为1   评价为0.402481
# 预测为1   实际为1   评价为0.518301
# 预测为1   实际为1   评价为0.580057
# 预测为1   实际为1   评价为0.734012
# 预测为1   实际为1   评价为0.548049
# 预测为0   实际为1   评价为0.439373
# 预测为1   实际为1   评价为0.521967
# 预测为1   实际为1   评价为0.780969
# 预测为1   实际为1   评价为0.530608
# 预测为0   实际为1   评价为0.305907
# 预测为0   实际为1   评价为0.474738
# 预测为1   实际为1   评价为0.507415
# 预测为1   实际为1   评价为0.554893
# 预测为1   实际为1   评价为0.765298
# 预测为0   实际为1   评价为0.172901
# 预测为0   实际为1   评价为0.374442
# 预测为1   实际为1   评价为0.501302
# 预测为0   实际为1   评价为0.348136
# 预测为0   实际为1   评价为0.354075
# 预测为0   实际为1   评价为0.425662
# 预测为0   实际为1   评价为0.338529
# 预测为1   实际为1   评价为0.546987
# 预测为0   实际为1   评价为0.335537
# 预测为0   实际为1   评价为0.391521
# 预测为1   实际为1   评价为0.712440
# 预测为0   实际为1   评价为0.483542
# 预测为0   实际为1   评价为0.474840
# 预测为1   实际为1   评价为0.634339
# 预测为1   实际为1   评价为0.726684
# 预测为1   实际为1   评价为0.526634
# 预测为1   实际为1   评价为0.652177
# 预测为1   实际为1   评价为0.836679
# 预测为1   实际为1   评价为0.629785
# 预测为1   实际为1   评价为0.510273
# 预测为1   实际为1   评价为0.610945
# 预测为0   实际为1   评价为0.487767
# 预测为1   实际为1   评价为0.556369
# 预测为1   实际为1   评价为0.742623
# 预测为0   实际为1   评价为0.453405
# 预测为1   实际为1   评价为0.633081
# 预测为0   实际为1   评价为0.409518
# 预测为1   实际为1   评价为0.728194
# 预测为1   实际为1   评价为0.684292
# 预测为0   实际为1   评价为0.318620
# 预测为0   实际为1   评价为0.058769
# 预测为0   实际为1   评价为0.135896
# 预测为0   实际为1   评价为0.077489
# 预测为1   实际为1   评价为0.686556
# 预测为1   实际为1   评价为0.684529
# 预测为1   实际为1   评价为0.689769
# 预测为1   实际为1   评价为0.710845
# 预测为0   实际为1   评价为0.405543
# 预测为0   实际为1   评价为0.201951
# 预测为0   实际为1   评价为0.344310
# 预测为0   实际为1   评价为0.275856
# 预测为1   实际为1   评价为0.564477
# 预测为0   实际为1   评价为0.493760
# 预测为0   实际为1   评价为0.414102
# 预测为0   实际为1   评价为0.344581
# 预测为1   实际为1   评价为0.701892
# 预测为0   实际为1   评价为0.114393
# 预测为0   实际为1   评价为0.435698
# 预测为1   实际为1   评价为0.676014
# 预测为0   实际为1   评价为0.367639
# 预测为1   实际为1   评价为0.507706
# 预测为0   实际为1   评价为0.128559
# 预测为0   实际为1   评价为0.079860
# 预测为0   实际为1   评价为0.110615
# 预测为1   实际为1   评价为0.687198
# 预测为1   实际为1   评价为0.639988
# 预测为0   实际为1   评价为0.465942
# 预测为1   实际为1   评价为0.672838
# 预测为1   实际为1   评价为0.706493
# 预测为1   实际为1   评价为0.639693
# 预测为1   实际为1   评价为0.676780
# 预测为0   实际为1   评价为0.031283
# 预测为0   实际为1   评价为0.046025
# 预测为0   实际为1   评价为0.035590
# 预测为0   实际为1   评价为0.028060
# 预测为0   实际为1   评价为0.149958
# 预测为0   实际为1   评价为0.369856
# 预测为0   实际为1   评价为0.201264
# 预测为0   实际为1   评价为0.269128
# 预测为1   实际为1   评价为0.648141
# 预测为1   实际为1   评价为0.557964
# 预测为1   实际为1   评价为0.670955
# 预测为0   实际为1   评价为0.426464
# 预测为1   实际为1   评价为0.737823
# 预测为1   实际为1   评价为0.592077
# 预测为0   实际为1   评价为0.445348
# 预测为1   实际为1   评价为0.741952
# 预测为1   实际为1   评价为0.635487
# 预测为1   实际为1   评价为0.516471
# 预测为1   实际为1   评价为0.756016
# 预测为0   实际为1   评价为0.498825
# 预测为1   实际为1   评价为0.758897
# 预测为0   实际为1   评价为0.375392
# 预测为1   实际为1   评价为0.634679
# 预测为0   实际为1   评价为0.378485
# 预测为1   实际为1   评价为0.697882
# 预测为1   实际为1   评价为0.691095
# 预测为1   实际为1   评价为0.690113
# 预测为1   实际为1   评价为0.700747
# 预测为1   实际为1   评价为0.718463
# 预测为0   实际为1   评价为0.404363
# 预测为0   实际为1   评价为0.386932
# 预测为0   实际为1   评价为0.285552
# 预测为1   实际为1   评价为0.682270
# 预测为0   实际为1   评价为0.310591
# 预测为1   实际为1   评价为0.631138
# 预测为0   实际为1   评价为0.109040
# 预测为0   实际为1   评价为0.376791
# 预测为0   实际为1   评价为0.259492
# 预测为1   实际为1   评价为0.517742
# 预测为0   实际为1   评价为0.113619
# 预测为0   实际为1   评价为0.226481
# 预测为1   实际为1   评价为0.744725
# 预测为0   实际为1   评价为0.315260
# 预测为0   实际为1   评价为0.245257
# 预测为0   实际为1   评价为0.296734
# 预测为1   实际为1   评价为0.531078
# 预测为1   实际为1   评价为0.626884
# 预测为0   实际为1   评价为0.433864
# 预测为0   实际为1   评价为0.342165
# 预测为1   实际为1   评价为0.858365
# 预测为1   实际为1   评价为0.801216
# 预测为1   实际为1   评价为0.649361
# 预测为0   实际为1   评价为0.342165
# 预测为1   实际为1   评价为0.734514
# 预测为1   实际为1   评价为0.745252
# 预测为1   实际为1   评价为0.616849
# 预测为1   实际为1   评价为0.720661
# 预测为1   实际为1   评价为0.632959
# 预测为0   实际为1   评价为0.457130
# 预测为1   实际为1   评价为0.645995
# 预测为1   实际为1   评价为0.528574
# 预测为0   实际为1   评价为0.055151
# 预测为0   实际为1   评价为0.041767
# 预测为0   实际为1   评价为0.101927
# 预测为1   实际为1   评价为0.680203
# 预测为0   实际为1   评价为0.490798
# 预测为0   实际为1   评价为0.390415
# 预测为1   实际为1   评价为0.872110
# 预测为1   实际为1   评价为0.656351
# 预测为1   实际为1   评价为0.583902
# 预测为1   实际为1   评价为0.525163
# 预测为1   实际为1   评价为0.520681
# 预测为1   实际为1   评价为0.628356
# 预测为1   实际为1   评价为0.612260
# 预测为1   实际为1   评价为0.788028
# 预测为0   实际为1   评价为0.241268
# 预测为1   实际为1   评价为0.712614
# 预测为1   实际为1   评价为0.569139
# 预测为0   实际为1   评价为0.391709
# 预测为0   实际为1   评价为0.303328
# 预测为1   实际为1   评价为0.560258
# 预测为0   实际为1   评价为0.404029
# 预测为0   实际为1   评价为0.412352
# 预测为0   实际为1   评价为0.417609
# 预测为0   实际为1   评价为0.200052
# 预测为0   实际为1   评价为0.002573
# 预测为0   实际为1   评价为0.293771
# 预测为0   实际为1   评价为0.053338
# 预测为0   实际为1   评价为0.181843
# 预测为0   实际为1   评价为0.203264
# 预测为0   实际为1   评价为0.434365
# 预测为0   实际为1   评价为0.239854
# 预测为1   实际为1   评价为0.507815
# 预测为1   实际为1   评价为0.733468
# 预测为1   实际为1   评价为0.636053
# 预测为0   实际为1   评价为0.224193
# 预测为0   实际为1   评价为0.415259
# 预测为0   实际为1   评价为0.388773
# 预测为0   实际为1   评价为0.350640
# 预测为0   实际为1   评价为0.480370
# 预测为1   实际为1   评价为0.579595
# 预测为1   实际为1   评价为0.709541
# 预测为1   实际为1   评价为0.591912
# 预测为0   实际为1   评价为0.213316
# 预测为1   实际为1   评价为0.679363
# 预测为1   实际为1   评价为0.668117
# 预测为0   实际为1   评价为0.177687
# 预测为0   实际为1   评价为0.194861
# 预测为0   实际为1   评价为0.048735
# 预测为0   实际为1   评价为0.342063
# 预测为0   实际为1   评价为0.316332
# 预测为0   实际为1   评价为0.091351
# 预测为0   实际为1   评价为0.333858
# 预测为0   实际为1   评价为0.297093
# 预测为0   实际为1   评价为0.311458
# 预测为0   实际为1   评价为0.429246
# 预测为1   实际为1   评价为0.859903
# 预测为0   实际为1   评价为0.244615
# 预测为0   实际为1   评价为0.454637
# 预测为0   实际为1   评价为0.281720
# 预测为1   实际为1   评价为0.632634
# 预测为1   实际为1   评价为0.609695
# 预测为1   实际为1   评价为0.511026
# 预测为1   实际为1   评价为0.581078
# 预测为1   实际为1   评价为0.638563
# 预测为1   实际为1   评价为0.652521
# 预测为1   实际为1   评价为0.574476
# 预测为0   实际为1   评价为0.255882
# 预测为1   实际为1   评价为0.652697
# 预测为1   实际为1   评价为0.585613
# 预测为0   实际为1   评价为0.178256
# 预测为1   实际为1   评价为0.756004
# 预测为0   实际为1   评价为0.283406
# 预测为0   实际为1   评价为0.232122
# 预测为0   实际为1   评价为0.378522
# 预测为0   实际为1   评价为0.356999
# 预测为0   实际为1   评价为0.487252
# 预测为0   实际为1   评价为0.353848
# 预测为1   实际为1   评价为0.693185
# 预测为1   实际为1   评价为0.723015
# 预测为0   实际为1   评价为0.216126
# 预测为1   实际为1   评价为0.588416
# 正确率为0.560302
